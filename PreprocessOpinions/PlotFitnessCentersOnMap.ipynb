# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
from geolocation_tools.geo_tools.locations import Locations, Helper
from sensible_raw.loaders import loader
import pandas as pd
import numpy as np
import preprocess_helper as ph
GMAPS_API_KEY = "AIzaSyBszAZvI9hvc9QW8we0aQqdMZXarY7J4GA"

from bokeh.io import output_notebook, show
from bokeh.plotting import figure, save, gmap
from bokeh.models import ColumnDataSource, HoverTool, CDSView, GMapOptions

cannot import name 'get_provider'

import shapely.geometry as gm
import geopandas as gpd
from typing import List
import matplotlib.pyplot as plt
size_mobile_friendly = {'plot_width': 400, 'plot_height': 600}
size_desktop = {'plot_width': 1200, 'plot_height': 800}
plot_size = size_mobile_friendly
output_notebook()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8e0732ee-ebc9-46f6-9b3a-d5d7200d2580">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-42-9420eb918977> in <module>()
#      21 output_notebook()
#      22 from bokeh.plotting import figure, show, output_file
# ---> 23 from bokeh.tile_providers import get_provider, Vendors
#
# ImportError: cannot import name 'get_provider'

# %%
from bokeh.plotting import figure, show, output_file
from bokeh.tile_providers import get_provider, Vendors

output_file("tile.html")

tile_provider = get_provider(Vendors.CARTODBPOSITRON)

# range bounds supplied in web mercator coordinates
p = figure(x_range=(-2000000, 6000000), y_range=(-1000000, 7000000),
           x_axis_type="mercator", y_axis_type="mercator")
p.add_tile(tile_provider)

show(p)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-b24e17c3a9cf> in <module>()
#       1 from bokeh.plotting import figure, show, output_file
# ----> 2 from bokeh.tile_providers import get_provider, Vendors
#       3
#       4 output_file("tile.html")
#       5
#
# ImportError: cannot import name 'get_provider'

# %%
sports = Locations(path='geolocation_tools/data/sports_and_fitness.geojson', name='sports places')

# %%
df = pd.DataFrame(
    {'City': ['Buenos Aires', 'Brasilia', 'Santiago', 'Bogota', 'Caracas'],
     'Country': ['Argentina', 'Brazil', 'Chile', 'Colombia', 'Venezuela'],
     'Latitude': [-34.58, -15.78, -33.45, 4.60, 10.48],
     'Longitude': [-58.66, -47.91, -70.66, -74.08, -66.86]})
gdf = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-3e8719f4b179> in <module>()
#       5      'Longitude': [-58.66, -47.91, -70.66, -74.08, -66.86]})
#       6 gdf = gpd.GeoDataFrame(
# ----> 7     df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))
#
# AttributeError: module 'geopandas' has no attribute 'points_from_xy'

# %%
#output_file("tile.html")

tile_provider = get_provider(Vendors.CARTODBPOSITRON)

# range bounds supplied in web mercator coordinates
p = figure(x_range=(-2000000, 6000000), y_range=(-1000000, 7000000),
           x_axis_type="mercator", y_axis_type="mercator")
p.add_tile(tile_provider)

show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-1a1db9f3a2bb> in <module>()
#       1 #output_file("tile.html")
#       2
# ----> 3 tile_provider = get_provider(Vendors.CARTODBPOSITRON)
#       4
#       5 # range bounds supplied in web mercator coordinates
#
# NameError: name 'get_provider' is not defined

# %%
sports[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-69d23146518d> in <module>()
# ----> 1 sports[0]
#
# TypeError: 'Locations' object does not support indexing
